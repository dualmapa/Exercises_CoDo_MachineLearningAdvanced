# %% [markdown]
# # Redes Convolucionales / Reducción de Dimensionalidad y Benchmarking de Modelos (Core)
#
# Reducción de Dimensionalidad y Benchmarking de Modelos (Core)
#
# Descripción:
#
# En este proyecto, aplicarás una combinación de técnicas avanzadas, comenzando por un análisis de reducción de dimensionalidad (como PCA) y luego realizarás un benchmark de diferentes modelos de machine learning para encontrar el que mejor se adecue a los objetivos específicos del dataset que has elegido.

# %% [markdown]
# ## Objetivo:
#
# El objetivo es realizar un análisis exhaustivo que comience con la reducción de dimensionalidad para simplificar el dataset y luego probar varios modelos de machine learning para determinar cuál ofrece el mejor rendimiento en términos de precisión, recall, F1-score u otras métricas relevantes para tu problema.

# %% [markdown]
# # 1. Selección del dataset:
#
#   – Utiliza el dataset que seleccionaste para el Proyecto 2 o elige uno adecuado de Kaggle que se relacione con tu área de interés. El dataset debe tener al menos 10 características y una variable objetivo clara.
#
#   – Realiza una exploración inicial para entender las variables y la relación que tienen con la variable objetivo.

# %% [markdown]
# ## dataset seleccionado
# Esta información es sacada de la página del dataset seleccionado, el link se muestra a continuación, así como información importante
# https://www.kaggle.com/datasets/bhanupratapbiswas/hr-analytics-case-study/data
#
#
# Acerca del conjunto de datos
#
# Analizar los datos de RR.HH. para mejorar la gestión de la mano de obra: Un estudio de caso
#
# Descripción de la organización:
# Consideremos una empresa tecnológica de tamaño medio llamada «TechSolutions Inc». La empresa está especializada en el desarrollo de software y cuenta con una plantilla diversa en diferentes departamentos, como ingeniería, marketing, ventas y atención al cliente.
#
# Objetivos:
# Los principales objetivos de este estudio de caso son los siguientes:
# 1. Comprender los factores que influyen en el abandono y la satisfacción laboral de los empleados.
# 2. Identificar los factores clave que predicen el rendimiento de los empleados.
# 3. Desarrollar estrategias para mejorar el compromiso y la retención de los empleados.
#
#
# Pasos del análisis de datos:
#
# 1. Preprocesamiento de datos: Limpiar y preparar los datos recopilados, tratar los valores que faltan y garantizar la calidad de los datos.
#
# 2. Análisis del abandono: Analizar los datos históricos para comprender los factores que contribuyen al abandono de los empleados, como el departamento, el nivel del puesto, el salario, la permanencia en el puesto, las calificaciones del rendimiento y los datos demográficos de los empleados.
#
# 3. Análisis de la satisfacción laboral: Explore los datos de las encuestas para identificar los factores clave de la satisfacción laboral, como el entorno de trabajo, las oportunidades de desarrollo profesional, la retribución y los beneficios para los empleados.
#
# 4. Predicción del rendimiento: Utilice técnicas de aprendizaje automático, como modelos de regresión o clasificación, para identificar predictores del rendimiento de los empleados basados en datos históricos de rendimiento, características de los empleados y otras variables relevantes.
#
# 5. Análisis del compromiso de los empleados: Analice los datos de las encuestas y los comentarios para evaluar los niveles de compromiso de los empleados e identificar áreas de mejora, como la comunicación, los programas de reconocimiento o las oportunidades de formación.
#
# 6. Información práctica: Obtenga información práctica a partir de los resultados del análisis para desarrollar estrategias dirigidas a mejorar la retención, la satisfacción laboral y el rendimiento de los empleados.
#
#
# RESULTADOS Y RECOMENDACIONES
#
# Basándonos en el análisis realizado en los pasos anteriores, vamos a asumir los siguientes resultados y las correspondientes recomendaciones:
#
# Análisis del desgaste:
#
# Identificación: Se observa una elevada rotación de empleados en el departamento de ventas, especialmente entre los empleados de nivel inferior.
# Recomendaciones: Implantar programas de tutoría, iniciativas de desarrollo profesional y evaluaciones periódicas del rendimiento para apoyar a los empleados de ventas junior y mejorar su satisfacción laboral.
# Análisis de la satisfacción laboral:
#
# Factores clave: La retribución, las oportunidades de crecimiento y promoción, y el equilibrio entre la vida laboral y personal se identifican como factores clave que afectan a la satisfacción laboral.
# Recomendaciones: Realizar un análisis comparativo de salarios para garantizar una retribución competitiva. Aplicar incentivos basados en el rendimiento, programas de desarrollo profesional y acuerdos laborales flexibles para mejorar la satisfacción laboral.
#
# Predicción del rendimiento:
#
# Factores predictivos: La antigüedad de los empleados, las calificaciones previas de rendimiento y las puntuaciones de las encuestas de compromiso se identifican como factores predictivos clave del rendimiento futuro.
# Recomendaciones: Implantar programas de incorporación específicos para mejorar la retención de los empleados. Proporcionar regularmente feedback y coaching para mejorar el rendimiento. Identificar a los empleados con mayor potencial para ofrecerles oportunidades de promoción profesional.
# Análisis del compromiso de los empleados:
#
# Niveles de compromiso: Se observan bajos niveles de compromiso en el departamento de ingeniería, posiblemente debido a las limitadas oportunidades de desarrollo profesional y a las lagunas de comunicación.
# Recomendaciones: Establecer trayectorias profesionales claras, ofrecer oportunidades de formación y desarrollo, y fomentar una cultura de comunicación abierta y retroalimentación dentro del departamento de ingeniería.
#
# Mediante la aplicación de estas recomendaciones, TechSolutions Inc. puede mejorar la satisfacción, el compromiso y la retención de los empleados, lo que dará lugar a una plantilla más productiva y motivada.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/content/10_Core_WA_Fn-UseC_-HR-Employee-Attrition.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
# Verificando si hay datos nulos (%)
print("Valores nulos:")
print((df.isnull().sum() * 100 / len(df)).round(2))
print("\n")

# Verificando si hay duplicados
print("Valores duplicados:")
print(df.duplicated().sum())
print("\n")
# Out:
# Valores nulos:
# Age                         0.0
# Attrition                   0.0
# BusinessTravel              0.0
# DailyRate                   0.0
# Department                  0.0
# DistanceFromHome            0.0
# Education                   0.0
# EducationField              0.0
# EmployeeCount               0.0
# EmployeeNumber              0.0
# EnvironmentSatisfaction     0.0
# Gender                      0.0
# HourlyRate                  0.0
# JobInvolvement              0.0
# JobLevel                    0.0
# JobRole                     0.0
# JobSatisfaction             0.0
# MaritalStatus               0.0
# MonthlyIncome               0.0
# MonthlyRate                 0.0
# NumCompaniesWorked          0.0
# Over18                      0.0
# OverTime                    0.0
# PercentSalaryHike           0.0
# PerformanceRating           0.0
# RelationshipSatisfaction    0.0
# StandardHours               0.0
# StockOptionLevel            0.0
# ...

# %%
# Detectar outliers en variables numéricas
def outliers_IQR(df):
    # Filtrar solo columnas numéricas
    numeric_columns = df.select_dtypes(include=['number']).columns

    for col in numeric_columns:
        Q1 = df[col].quantile(0.25)  # Primer cuartil
        Q3 = df[col].quantile(0.75)  # Tercer cuartil
        IQR = Q3 - Q1               # Rango intercuartílico

        # Definir los límites inferior y superior de los valores atípicos
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Identificar outliers
        outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
        print(f"\n🚩 Outliers detected in {col}: {outliers.shape[0]}")

        # Opcional: Remover outliers
        # df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

# Llamar a la función
outliers_IQR(df)
# Out:
# 🚩 Outliers detected in Age: 0
#
# 🚩 Outliers detected in DailyRate: 0
#
# 🚩 Outliers detected in DistanceFromHome: 0
#
# 🚩 Outliers detected in Education: 0
#
# 🚩 Outliers detected in EmployeeCount: 0
#
# 🚩 Outliers detected in EmployeeNumber: 0
#
# 🚩 Outliers detected in EnvironmentSatisfaction: 0
#
# 🚩 Outliers detected in HourlyRate: 0
#
# 🚩 Outliers detected in JobInvolvement: 0
#
# 🚩 Outliers detected in JobLevel: 0
#
# 🚩 Outliers detected in JobSatisfaction: 0
#
# 🚩 Outliers detected in MonthlyIncome: 114
#
# 🚩 Outliers detected in MonthlyRate: 0
#
# 🚩 Outliers detected in NumCompaniesWorked: 52
#
# 🚩 Outliers detected in PercentSalaryHike: 0
#
# 🚩 Outliers detected in PerformanceRating: 226
#
# 🚩 Outliers detected in RelationshipSatisfaction: 0
#
# 🚩 Outliers detected in StandardHours: 0
#
# 🚩 Outliers detected in StockOptionLevel: 85
#
# 🚩 Outliers detected in TotalWorkingYears: 63
#
# 🚩 Outliers detected in TrainingTimesLastYear: 238
#
# ...

# %%
def vis_hist_boxplot(df):
    for i in df.columns:
        fig, ax = plt.subplots(figsize=(15, 5), nrows=1, ncols=2)
        sns.set(style="white", palette="muted", color_codes=True)
        sns.despine(left=True)

        # Histograma con kde
        sns.histplot(data=df, x=i, kde=True, ax=ax[0]).set_xlabel(f"{i}")
        ax[0].set_ylabel('Frecuencia')
        # Boxplot
        sns.boxplot(data=df, x=i, ax=ax[1])

        plt.tight_layout()
        plt.show()

vis_hist_boxplot(df)

# %%
attrition_counts = df['Attrition'].value_counts()
attrition_counts
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
# Esto es código de Claude
from scipy.stats import chi2_contingency

def cramers_v(var1, var2):
    crosstab = pd.crosstab(var1, var2)
    chi2 = chi2_contingency(crosstab)[0]
    n = crosstab.sum().sum()
    min_dim = min(crosstab.shape) - 1
    return np.sqrt(chi2 / (n * min_dim))

# Seleccionar todas las columnas categóricas excepto la variable objetivo
target_col = 'Attrition'
categorical_cols = df.select_dtypes(include=['object','int','float']).columns
other_cols = [col for col in categorical_cols if col != target_col]

# Calcular V de Cramer para cada columna con respecto a AI_Satisfication
cramer_scores = {}
for col in other_cols:
    cramer_scores[col] = cramers_v(df[target_col], df[col])

# Convertir a Series y ordenar
cramer_results = pd.Series(cramer_scores).sort_values(ascending=False)

print(f"\nAsociaciones con {target_col} usando V de Cramer:")
print(cramer_results)

# V de Cramer: medida estadística evalúa fuerza de asociación entre variables categóricas, basada en estadística chi-cuadrado.
# Sus valores van de 0 a 1, donde: 0 significa que no hay asociación, 1 significa una asociación perfecta…
# < 0.1: asociación muy débil, 0.1 - 0.3: asociación débil, 0.3 - 0.5: asociación moderada, >0.5: asociación fuerte

# La ventaja del V de Cramer es que:
# Funciona con variables categóricas de cualquier número de categorías
# Es simétrica (el orden de las variables no importa)
# Es normalizada (siempre va de 0 a 1)
# No asume ninguna distribución específica de los datos
# Out:
# <ipython-input-63-cf519058cb9e>:9: RuntimeWarning: invalid value encountered in divide
#   return np.sqrt(chi2 / (n * min_dim))
# <ipython-input-63-cf519058cb9e>:9: RuntimeWarning: invalid value encountered in divide
#   return np.sqrt(chi2 / (n * min_dim))
# <ipython-input-63-cf519058cb9e>:9: RuntimeWarning: invalid value encountered in divide
#   return np.sqrt(chi2 / (n * min_dim))
# Asociaciones con Attrition usando V de Cramer:
# EmployeeNumber              1.000000
# MonthlyRate                 0.977530
# MonthlyIncome               0.947257
# DailyRate                   0.769980
# TotalWorkingYears           0.288442
# Age                         0.284730
# YearsAtCompany              0.254736
# OverTime                    0.244065
# JobRole                     0.242142
# YearsWithCurrManager        0.225300
# JobLevel                    0.222125
# HourlyRate                  0.221358
# YearsInCurrentRole          0.209146
# StockOptionLevel            0.203035
# ...

# %%
# Filtrar las columnas con V de Cramer > 0.1
selected_cols = cramer_results[cramer_results > 0.1].index.tolist()

# Agregar la variable objetivo a la lista de columnas seleccionadas
selected_cols.append(target_col)

# Crear un nuevo DataFrame con las columnas seleccionadas
df_selected = df[selected_cols]

# Mostrar el nuevo DataFrame
print("\nNuevo DataFrame con V de Cramer > 0.1:")
print(df_selected.info())
# Out:
# Nuevo DataFrame con V de Cramer > 0.1:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeNumber           1470 non-null   int64
#  1   MonthlyRate              1470 non-null   int64
#  2   MonthlyIncome            1470 non-null   int64
#  3   DailyRate                1470 non-null   int64
#  4   TotalWorkingYears        1470 non-null   int64
#  5   Age                      1470 non-null   int64
#  6   YearsAtCompany           1470 non-null   int64
#  7   OverTime                 1470 non-null   object
#  8   JobRole                  1470 non-null   object
#  9   YearsWithCurrManager     1470 non-null   int64
#  10  JobLevel                 1470 non-null   int64
#  11  HourlyRate               1470 non-null   int64
#  12  YearsInCurrentRole       1470 non-null   int64
# ...

# %%
# Eliminar EmployeeNumber de df_selected
df_selected = df_selected.drop('EmployeeNumber', axis=1)

# %%
# Mostrar solo los que tienen outliers (mayor a 0)
for col in df_selected.select_dtypes(include=['number']).columns:
    result = df_selected[(df_selected[col] < df_selected[col].quantile(0.25) - 1.5 * (df_selected[col].quantile(0.75) - df_selected[col].quantile(0.25))) |
                        (df_selected[col] > df_selected[col].quantile(0.75) + 1.5 * (df_selected[col].quantile(0.75) - df_selected[col].quantile(0.25)))]
    if len(result) > 0:
        print(f"\n🚩 Outliers detected in {col}: {len(result)}")
# Out:
# 🚩 Outliers detected in MonthlyIncome: 114
#
# 🚩 Outliers detected in TotalWorkingYears: 63
#
# 🚩 Outliers detected in YearsAtCompany: 104
#
# 🚩 Outliers detected in YearsWithCurrManager: 14
#
# 🚩 Outliers detected in YearsInCurrentRole: 21
#
# 🚩 Outliers detected in StockOptionLevel: 85
#
# 🚩 Outliers detected in NumCompaniesWorked: 52
#
# 🚩 Outliers detected in YearsSinceLastPromotion: 107
#
# 🚩 Outliers detected in TrainingTimesLastYear: 238

# %%
# Lista de variables con outliers
variables_outliers = [
    'MonthlyIncome', 'TotalWorkingYears', 'YearsAtCompany',
    'YearsWithCurrManager', 'YearsInCurrentRole', 'StockOptionLevel',
    'NumCompaniesWorked', 'YearsSinceLastPromotion', 'TrainingTimesLastYear'
]

# Ver tipos de datos
print("Tipos de datos:")
print(df_selected[variables_outliers].dtypes)
print("\n")

# Configurar el estilo de las gráficas
fig, axes = plt.subplots(len(variables_outliers), 2, figsize=(15, 5*len(variables_outliers)))
fig.suptitle('Distribución de Variables con Outliers', y=1.02, size=16)

# Crear histogramas y boxplots
for idx, var in enumerate(variables_outliers):
    # Histograma
    sns.histplot(data=df_selected, x=var, ax=axes[idx,0])
    axes[idx,0].set_title(f'Histograma de {var}')

    # Boxplot
    sns.boxplot(data=df_selected, x=var, ax=axes[idx,1])
    axes[idx,1].set_title(f'Boxplot de {var}')

plt.tight_layout()
plt.show()
print("\n")

# Estadísticas descriptivas
print("Estadísticas descriptivas:")
print(df_selected[variables_outliers].describe())
# Out:
# Tipos de datos:
# MonthlyIncome              int64
# TotalWorkingYears          int64
# YearsAtCompany             int64
# YearsWithCurrManager       int64
# YearsInCurrentRole         int64
# StockOptionLevel           int64
# NumCompaniesWorked         int64
# YearsSinceLastPromotion    int64
# TrainingTimesLastYear      int64
# dtype: object
# Estadísticas descriptivas:
#        MonthlyIncome  TotalWorkingYears  YearsAtCompany  YearsWithCurrManager  \
# count    1470.000000        1470.000000     1470.000000           1470.000000
# mean     6502.931293          11.279592        7.008163              4.123129
# std      4707.956783           7.780782        6.126525              3.568136
# min      1009.000000           0.000000        0.000000              0.000000
# 25%      2911.000000           6.000000        3.000000              2.000000
# 50%      4919.000000          10.000000        5.000000              3.000000
# ...

# %%
# Cambiar tipo de dato 'MonthlyIncome' int a float
df_selected['MonthlyIncome'] = df_selected['MonthlyIncome'].astype(float)

print(df_selected.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   MonthlyRate              1470 non-null   int64
#  1   MonthlyIncome            1470 non-null   float64
#  2   DailyRate                1470 non-null   int64
#  3   TotalWorkingYears        1470 non-null   int64
#  4   Age                      1470 non-null   int64
#  5   YearsAtCompany           1470 non-null   int64
#  6   OverTime                 1470 non-null   object
#  7   JobRole                  1470 non-null   object
#  8   YearsWithCurrManager     1470 non-null   int64
#  9   JobLevel                 1470 non-null   int64
#  10  HourlyRate               1470 non-null   int64
#  11  YearsInCurrentRole       1470 non-null   int64
#  12  StockOptionLevel         1470 non-null   int64
#  13  MaritalStatus            1470 non-null   object
# ...

# %%
# Transformación logarítmica
df_selected['MonthlyIncome_log'] = np.log(df_selected['MonthlyIncome'])

# Transformación raíz cuadrada
df_selected['MonthlyIncome_sqrt'] = np.sqrt(df_selected['MonthlyIncome'])

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Original
sns.histplot(data=df_selected, x='MonthlyIncome', ax=axes[0])
axes[0].set_title('Original')

# Log
sns.histplot(data=df_selected, x='MonthlyIncome_log', ax=axes[1])
axes[1].set_title('Log Transform')

# Sqrt
sns.histplot(data=df_selected, x='MonthlyIncome_sqrt', ax=axes[2])
axes[2].set_title('Sqrt Transform')

plt.tight_layout()
plt.show()

# %%
outliers_IQR(df_selected[['MonthlyIncome','MonthlyIncome_log','MonthlyIncome_sqrt']])
# Out:
# 🚩 Outliers detected in MonthlyIncome: 114
#
# 🚩 Outliers detected in MonthlyIncome_log: 0
#
# 🚩 Outliers detected in MonthlyIncome_sqrt: 0

# %%
df_cleaned = df_selected.drop(['MonthlyIncome', 'MonthlyIncome_log'], axis=1)

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   MonthlyRate              1470 non-null   int64
#  1   DailyRate                1470 non-null   int64
#  2   TotalWorkingYears        1470 non-null   int64
#  3   Age                      1470 non-null   int64
#  4   YearsAtCompany           1470 non-null   int64
#  5   OverTime                 1470 non-null   object
#  6   JobRole                  1470 non-null   object
#  7   YearsWithCurrManager     1470 non-null   int64
#  8   JobLevel                 1470 non-null   int64
#  9   HourlyRate               1470 non-null   int64
#  10  YearsInCurrentRole       1470 non-null   int64
#  11  StockOptionLevel         1470 non-null   int64
#  12  MaritalStatus            1470 non-null   object
#  13  DistanceFromHome         1470 non-null   int64
# ...

# %%
# Análisis de variables categóricas
categorical_cols = df_cleaned.select_dtypes(include=['object']).columns
print("\nVariables categóricas:")
print(categorical_cols)
print("\nCantidad de variables categóricas:", len(categorical_cols))

for col in categorical_cols:
    print(f"\nValores únicos de '{col}':")
    print(df_cleaned[col].value_counts())
# Out:
# Variables categóricas:
# Index(['OverTime', 'JobRole', 'MaritalStatus', 'BusinessTravel',
#        'EducationField', 'Attrition'],
#       dtype='object')
#
# Cantidad de variables categóricas: 6
#
# Valores únicos de 'OverTime':
# OverTime
# No     1054
# Yes     416
# Name: count, dtype: int64
#
# Valores únicos de 'JobRole':
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64
#
# Valores únicos de 'MaritalStatus':
# MaritalStatus
# Married     673
# Single      470
# Divorced    327
# Name: count, dtype: int64
#
# Valores únicos de 'BusinessTravel':
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64
#
# ...

# %%
categorical_cols
# Out:
# Index(['OverTime', 'JobRole', 'MaritalStatus', 'BusinessTravel',
#        'EducationField', 'Attrition'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# Crea una instancia de LabelEncoder
le = LabelEncoder()

# Aplica Label Encoding a las columnas 'Attrition' y 'OverTime'
df_cleaned['Attrition'] = le.fit_transform(df_cleaned['Attrition'])
df_cleaned['OverTime'] = le.fit_transform(df_cleaned['OverTime'])

# Eliminar las columnas especificadas
columns_to_drop = ['JobRole', 'MaritalStatus', 'BusinessTravel', 'EducationField']
df_cleaned = df_cleaned.drop(columns=columns_to_drop, errors='ignore')

df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   MonthlyRate              1470 non-null   int64
#  1   DailyRate                1470 non-null   int64
#  2   TotalWorkingYears        1470 non-null   int64
#  3   Age                      1470 non-null   int64
#  4   YearsAtCompany           1470 non-null   int64
#  5   OverTime                 1470 non-null   int64
#  6   YearsWithCurrManager     1470 non-null   int64
#  7   JobLevel                 1470 non-null   int64
#  8   HourlyRate               1470 non-null   int64
#  9   YearsInCurrentRole       1470 non-null   int64
#  10  StockOptionLevel         1470 non-null   int64
#  11  DistanceFromHome         1470 non-null   int64
#  12  JobInvolvement           1470 non-null   int64
#  13  NumCompaniesWorked       1470 non-null   int64
# ...

# %% [markdown]
# ## Análisis
#
# Decidí trabajar con un dataset diferente, sobre recursos humanos para predecir si la persona está desgastada y renuncia.
#
# Para ellos se cagó el dataset, se revisaron nulos y duplicados, y no se encontraron, también se revisaron outliers y estos se presentaron en varias variables.
#
# Al ver las distribuciones en histogramas y boxplot para las variables, se puede apreciar que si bien hay outliers, en muchas de las variables son int y son valores ordinales y no continuos, por lo que su tratamiento puede ser complejo y la eliminación implicaría perder información importante.
#
# Además se revisó la variable objetivo (Attrition) y se encontró que tiene dos niveles, pero un desbalance de clases bastante fuerte (84% No y 16% Si)
#
# Decidí que en esta ocasión trabajar con todas las características no era muy viable dado el objetivo puntual del análisis, así que revisé correlaciones con la asociación de Cramer para seleccionar solo aquellas que fueran mayores a 0.1, eliminándose aquellas que dieran una correlación de 1 dado posibles problemas de multicolinealidad en los modelados, aunque si somos prácticos, correlaciones de más de 0.9 son muy buenas para indicar dependencias fuertes, de modo que en análisis exploratorios son variables altamente relacionadas, pero en modelados también podrían generar problemas de multicolinealidad como las que tienen “correlación” o asociación de 1.
#
# Puntualmente, una de las variables con outliers, se transformó de int a float y se aplicaron transformaciones logarítmicas y cuadráticas para el tratamiento de estos, y se decidió dejar la transformación cuadrática dado que, al revisar la distribución, la logarítmica estaba bastante diferente a la distribución original de la variable, mientras que la cuadrática si bien es diferente, parece tener similitudes (dadas las escalas). Así que se eliminaron la variable original y la transformación logarítmica. Aunque ambas trasformaciones llevaron a cero los outliers en esta variable
#
# En cuanto a las variables categóricas, dado la practicidad del ejercicio y el objetivo del siguiente punto, para 4 de las 6 variables en este df seleccionado, tienen más de dos niveles, lo que implica que habría que hacerse codificación con One Hot Encoding, lo que aumentaría bastante la dimensionalidad, y después aplicar PCA sería bastante complejo (según como lo veo), así que eliminé aquellas 4, y las dos restantes (la objetivo y otra), apliqué Label Encoder ya que solo tenían dos niveles

# %% [markdown]
# # 2. Reducción de dimensionalidad:
#
#   – Implementa un análisis de reducción de dimensionalidad utilizando PCA (u otra técnica adecuada). El objetivo es reducir el número de características, manteniendo al menos el 80-90% de la variabilidad original.
#
#   – Visualiza los componentes principales y discute cómo contribuyen a la variabilidad del dataset.
#
#   – Utiliza las características reducidas para simplificar el conjunto de datos.

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Separar características y variable objetivo
X = df_cleaned.drop(columns=['Attrition'])
y = df_cleaned['Attrition']

# Normalización de los datos
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Reducción de dimensionalidad con PCA
pca = PCA(n_components=0.90)  # Mantiene el 90% de la varianza
X_pca = pca.fit_transform(X_scaled)

# %%
# Visualización de la varianza explicada
plt.figure(figsize=(10,5))
plt.plot(range(1, len(pca.explained_variance_ratio_)+1), np.cumsum(pca.explained_variance_ratio_), marker='o', linestyle='--')
plt.xlabel('Número de Componentes')
plt.ylabel('Varianza Explicada Acumulada')
plt.title('Análisis de Componentes Principales (PCA)')

# Agregar líneas horizontales en y = 0.8 y y = 0.9
plt.axhline(y=0.8, color='r', linestyle='-', label='80% Varianza Explicada')
plt.axhline(y=0.9, color='g', linestyle='-', label='90% Varianza Explicada')

# Líneas verticales
plt.axvline(x=11, color='b', linestyle=':', label='11 Componentes')
plt.axvline(x=14, color='m', linestyle=':', label='14 Componentes')

# Mostrar la leyenda
plt.legend()

plt.show()

# %% [markdown]
# ## Análisis
#
# Si bien en el punto anterior, se pasó de 35 variables del dataset original, a un “dataset limpio” con 21 variables, al realizarse el escalado y aplicar la reducción de dimensionalidad con PCA, se pasa a 11 componentes principales que explican el 80% de la varianza o a 14 componentes principales que explican el 90% de la varianza. Si bien el código está, los análisis siguientes serán de pantallazos de los dos casos, para tener comparativas

# %% [markdown]
# # 3. Benchmarking de modelos:
#   – Implementa y compara al menos tres modelos de machine learning en el dataset reducido. Algunos ejemplos de modelos que puedes utilizar incluyen:
#
#     – Regresión logística
#     – Árboles de decisión
#     – Random Forest
#     – Support Vector Machines (SVM)
#
#   – Para cada modelo, utiliza validación cruzada para medir su rendimiento de manera consistente. Registra las métricas más importantes, como la precisión, el recall, la F1-score y el AUC-ROC.

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Benchmarking de modelos
def evaluate_model(model, X, y):
    scores = cross_val_score(model, X, y, cv=5, scoring='accuracy')
    return np.mean(scores)

# División en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.2, random_state=42)

# Modelos a evaluar
models = {
    "Logistic Regression": LogisticRegression(class_weight='balanced', random_state=42),
    "Decision Tree": DecisionTreeClassifier(class_weight='balanced', random_state=42),
    "Random Forest": RandomForestClassifier(class_weight='balanced', random_state=42),
    "SVM": SVC(probability=True, class_weight='balanced', random_state=42)
}

# Evaluación de modelos
results = {}
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    results[name] = {
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred, average='weighted'),
        "Recall": recall_score(y_test, y_pred, average='weighted'),
        "F1 Score": f1_score(y_test, y_pred, average='weighted')
    }

df_results = pd.DataFrame(results).T
print(df_results)
# Out:
#                      Accuracy  Precision    Recall  F1 Score
# Logistic Regression  0.782313   0.868410  0.782313  0.810640
# Decision Tree        0.809524   0.817607  0.809524  0.813417
# Random Forest        0.880952   0.895320  0.880952  0.836325
# SVM                  0.823129   0.856332  0.823129  0.836475

# %% [markdown]
# ## Análisis
#
# Se cargó todo lo necesario para el benchmarking, tanto los modelos, la validación cruzada y el dividir nuevamente los datos tomando los X transformados o tratados con PCA.
#
# En este caso, se trato de manejar el desbalanceo de clases con class_weight='balanced' en todos los modelos solicitados, y finalmente se calcularon las métricas para estos modelos, y se imprimieron en un df
#
# - Con 14 componentes (90% varianza) los resultados en las métricas son:
#  ![image.png](data:image/png;base64,...)
#
#
# - Con 11 componentes (80% varianza) los resultados en las métricas son:
# ![image.png](data:image/png;base64,...)
#
# Se puede observar que, dependiendo del modelo, estas métricas cambian bastante conforme si se usan 11 o 14 componentes, y en general los mejores modelos son Random Forest y SVM

# %% [markdown]
# # 4. Análisis comparativo de modelos:
#
#   – Compara los modelos en base a las métricas obtenidas. Discute cuál de los modelos es más adecuado para resolver el problema en cuestión y por qué.
#
#   – Si alguno de los modelos tiene un rendimiento significativamente inferior, analiza posibles causas y estrategias para mejorar el rendimiento (como ajustar hiperparámetros o utilizar técnicas de regularización).

# %%
# Análisis comparativo
plt.figure(figsize=(10, 5))
df_results.plot(kind='bar', figsize=(12, 6))
plt.title("Comparación de Modelos")
plt.xlabel("Modelo")
plt.ylabel("Métrica")
plt.legend(loc='best')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 5. Informe final:
#
# - Elabora un informe detallado que incluya:
#
#     – El análisis de reducción de dimensionalidad, mostrando cómo PCA (u otra técnica) ayudó a reducir el número de características sin perder información relevante.
#
#     – Un análisis comparativo de los modelos probados, con gráficos que muestren el rendimiento de cada modelo.
#
#     – Conclusiones y recomendaciones sobre cuál modelo utilizarías en un escenario real.

# %%
# Conclusión y selección del mejor modelo (90%)
best_model = df_results['F1 Score'].idxmax()
print(f"El mejor modelo es: {best_model}")
# Out:
# El mejor modelo es: SVM

# %%
# Conclusión y selección del mejor modelo (80%)
best_model = df_results['F1 Score'].idxmax()
print(f"El mejor modelo es: {best_model}")
# Out:
# El mejor modelo es: Random Forest

# %% [markdown]
# ## Análisis
#
# Si bien anteriormente se habían sugerido que estos dos modelos eran los mejores para este caso de clasificación (SVM y Random Forest), se puede apreciar qeu, por código, si se escogen 11 o 14 componentes, se recomienda un modelo diferente.
#
# Pero:
#
# - El mejor modelo para este problema, considerando el **desbalanceo de clases** y el rendimiento en F1 Score, es Random Forest. Su combinación de alta precisión y recall lo hace más confiable para clasificar ambas clases correctamente.
#
#
# Ya para mejorar métricas y rendimiento del modelo, sería aplicar optimización de hiperparámetros de forma tal que se mejoren, pero también habría que definir si es mejor con 11 o con 14 componentes, para mí, me parece mas viable con los 14 (90% de la varianza)
